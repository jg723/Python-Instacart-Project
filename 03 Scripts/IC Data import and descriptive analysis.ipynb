# %% [markdown]
#  Table of contents
#
# 01. Importing libraries
#
# 02. Importing data
#
# 03. Data Review

# %% [markdown]
#  # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# creating shortcut for folder location
path = r'/Users/tuor/DA Projects/230321 Instacart Basket Analysis'

# %%
# creating orders data frame
df1 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
# creating products data frame
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# # 03. Data Review

# %%
# looking at first 5 rows and all columns
df1.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# looking at first 30 rows and all columns
df1.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
# looking at last 5 rows and all columns

df_prods.tail()
# Out:
#        product_id                                product_name  aisle_id  \
# 49688       49684   Vodka, Triple Distilled, Twist of Vanilla       124
# 49689       49685          En Croute Roast Hazelnut Cranberry        42
# 49690       49686                            Artisan Baguette       112
# 49691       49687  Smartblend Healthy Metabolism Dry Cat Food        41
# 49692       49688                      Fresh Foaming Cleanser        73
#
#        department_id  prices
# 49688              5     5.3
# 49689              1     3.1
# 49690              3     7.8
# 49691              8     4.7
# 49692             11    13.5

# %%
# orders rows and columns numbers
df1.shape
# Out:
# (3421083, 7)

# %%
# products rows and columns numbers
df_prods.shape
# Out:
# (49693, 5)

# %%
# getting data types, non-null count, rows and columns and other info from info() function for products
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
# getting data types, non-null count, rows and columns and other info from info() function for products
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %%
# another way of finding columns
df1.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
# getting count, mean, standard deviation, minimum, max, etc. for orders data frame
df1.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# ### Reviewing a smaller set of data to evaluate columns for removal

# %%
# 1000 row data frame from orders data set
dfreview = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), nrows=1000)

# %%
# getting data types, non-null count, rows and columns and other info from info() function for products
dfreview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                1000 non-null   int64
#  1   user_id                 1000 non-null   int64
#  2   eval_set                1000 non-null   object
#  3   order_number            1000 non-null   int64
#  4   order_dow               1000 non-null   int64
#  5   order_hour_of_day       1000 non-null   int64
#  6   days_since_prior_order  936 non-null    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 54.8+ KB

# %% [markdown]
# ### Importing with the columns that are desired for the import

# %%
# creating dictionary of column names desired
vars_list = ['order_id',
             'user_id',
             'order_number',
             'order_dow',
             'order_hour_of_day',
             'days_since_prior_order']

# %%
# selecting only columns listed in dictionary
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
# using info to confirm columns used
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   order_dow               int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(5)
# memory usage: 156.6 MB

# %%
# reviewing data
print(df.head(5))
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# reviewing data
print(df_prods.head(20))
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
# reviewing data
print(df_prods.tail(35))
# Out:
#        product_id                                       product_name  \
# 49658       49654                   Teriyaki Sauce, Sesame, Original
# 49659       49655                                        Apple Cider
# 49660       49656                         Masada Kosher Pocket Bread
# 49661       49657                                  Cabernet Tomatoes
# 49662       49658                         Brie with Herbs Foil Wedge
# 49663       49659                            Organic Creamed Coconut
# 49664       49660                        Professionals Sleek Shampoo
# 49665       49661                                              Porto
# 49666       49662                       Bacon Cheddar Pretzel Pieces
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49668       49664                     Lemon Cayenne Drinking Vinegar
# 49669       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49670       49666                      Ginger Snaps Snacking Cookies
# ...

# %%
# reviewing data
print(df_prods.shape)
# Out:
# (49693, 5)

# %%
# getting count, mean, standard deviation, minimum, max, etc. for products data frame
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
# getting data types, non-null count, rows and columns and other info from info() function for products
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# What’s the maximum value of the “aisle_id” column?
# - 134
#
# What’s the data type of the “department_id” column?
# - int64
